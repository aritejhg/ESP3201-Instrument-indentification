# %% [markdown]
# # Download OpenMIC Dataset

# %%
# Download original zip
# !wget https://zenodo.org/record/1432913/files/openmic-2018-v1.0.0.tgz
# Out:
# --2022-10-15 13:16:18--  https://zenodo.org/record/1432913/files/openmic-2018-v1.0.0.tgz
# Resolving zenodo.org (zenodo.org)... 188.184.117.155
# Connecting to zenodo.org (zenodo.org)|188.184.117.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623376754 (2.4G) [application/octet-stream]
# Saving to: 'openmic-2018-v1.0.0.tgz'
#
# openmic-2018-v1.0.0 100%[===================>]   2.44G  27.3MB/s    in 94s
#
# 2022-10-15 13:17:53 (26.5 MB/s) - 'openmic-2018-v1.0.0.tgz' saved [2623376754/2623376754]

# %%
# Extract and delete the zip
# !tar --extract --file openmic-2018-v1.0.0.tgz
# !rm openmic-2018-v1.0.0.tgz

# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (0.9.2)
# Requirement already satisfied: audioread>=2.1.9 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from librosa) (3.0.0)
# Requirement already satisfied: joblib>=0.14 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.0.10 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: pooch>=1.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from librosa) (1.6.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from librosa) (1.1.2)
# Requirement already satisfied: numba>=0.45.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from librosa) (0.56.3)
# Requirement already satisfied: soundfile>=0.10.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from librosa) (0.11.0)
# Requirement already satisfied: resampy>=0.2.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from librosa) (0.4.2)
# Requirement already satisfied: packaging>=20.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from librosa) (21.3)
# Requirement already satisfied: scipy>=1.2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from librosa) (1.9.2)
# Requirement already satisfied: numpy>=1.17.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from librosa) (1.23.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (0.39.1)
# Requirement already satisfied: setuptools in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (65.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from pooch>=1.0->librosa) (2.28.1)
# Requirement already satisfied: appdirs>=1.3.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)

# %%
# %conda install -c conda-forge librosa
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/studio-lab-user/.conda/envs/default
#
#   added / updated specs:
#     - librosa
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.5.0                  |       h27087fc_0         2.7 MB  conda-forge
#     appdirs-1.4.4              |     pyh9f0ad1d_0          13 KB  conda-forge
#     audioread-3.0.0            |   py39hf3d152e_0          34 KB  conda-forge
#     brotli-1.0.9               |       h166bdaf_7          18 KB  conda-forge
#     brotli-bin-1.0.9           |       h166bdaf_7          19 KB  conda-forge
#     brotlipy-0.7.0             |py39hb9d737c_1004         342 KB  conda-forge
#     certifi-2022.9.24          |     pyhd8ed1ab_0         155 KB  conda-forge
#     charset-normalizer-2.1.1   |     pyhd8ed1ab_0          36 KB  conda-forge
#     contourpy-1.0.5            |   py39hf939315_0         234 KB  conda-forge
#     cryptography-38.0.2        |   py39hd97740a_0         1.5 MB  conda-forge
#     cycler-0.11.0              |     pyhd8ed1ab_0          10 KB  conda-forge
#     expat-2.4.9                |       h27087fc_0         189 KB  conda-forge
#     ffmpeg-5.1.2               | gpl_he10e716_101        10.4 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       hab24e00_0         1.9 MB  conda-forge
#     fontconfig-2.14.0          |       hc2a2eb6_1         318 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     fonttools-4.37.4           |   py39hb9d737c_0         1.9 MB  conda-forge
#     freetype-2.12.1            |       hca18f0e_0         884 KB  conda-forge
#     gettext-0.21.1             |       h27087fc_0         4.1 MB  conda-forge
#     gmp-6.2.1                  |       h58526e2_0         806 KB  conda-forge
#     gnutls-3.7.8               |       hf3e180e_0         2.2 MB  conda-forge
#     idna-3.4                   |     pyhd8ed1ab_0          55 KB  conda-forge
#     joblib-1.2.0               |     pyhd8ed1ab_0         205 KB  conda-forge
#     jpeg-9e                    |       h166bdaf_2         269 KB  conda-forge
#     kiwisolver-1.4.4           |   py39hf939315_0          76 KB  conda-forge
#     lame-3.100                 |    h166bdaf_1003         496 KB  conda-forge
#     lcms2-2.12                 |       hddcbb42_0         443 KB  conda-forge
#     lerc-4.0.0                 |       h27087fc_0         275 KB  conda-forge
#     libbrotlicommon-1.0.9      |       h166bdaf_7          65 KB  conda-forge
#     libbrotlidec-1.0.9         |       h166bdaf_7          33 KB  conda-forge
#     libbrotlienc-1.0.9         |       h166bdaf_7         287 KB  conda-forge
#     libdeflate-1.14            |       h166bdaf_0          81 KB  conda-forge
#     libdrm-2.4.113             |       h166bdaf_0         286 KB  conda-forge
#     libflac-1.4.1              |       h27087fc_0         405 KB  conda-forge
#     libidn2-2.3.3              |       h166bdaf_0         155 KB  conda-forge
#     libllvm11-11.1.0           |       he0ac6c6_4        28.8 MB  conda-forge
#     libogg-1.3.4               |       h7f98852_1         206 KB  conda-forge
#     libopus-1.3.1              |       h7f98852_1         255 KB  conda-forge
#     libpciaccess-0.16          |       h516909a_0          37 KB  conda-forge
#     libpng-1.6.38              |       h753d276_0         371 KB  conda-forge
#     librosa-0.9.2              |     pyhd8ed1ab_0         156 KB  conda-forge
#     libsndfile-1.1.0           |       h27087fc_0         370 KB  conda-forge
#     libtasn1-4.19.0            |       h166bdaf_0         114 KB  conda-forge
#     libtiff-4.4.0              |       h55922b4_4         651 KB  conda-forge
#     libunistring-0.9.10        |       h7f98852_0         1.4 MB  conda-forge
#     libva-2.16.0               |       h166bdaf_0         186 KB  conda-forge
#     libvorbis-1.3.7            |       h9c3ff4c_0         280 KB  conda-forge
#     libvpx-1.11.0              |       h9c3ff4c_3         1.1 MB  conda-forge
#     libwebp-base-1.2.4         |       h166bdaf_0         404 KB  conda-forge
#     libxcb-1.13                |    h7f98852_1004         391 KB  conda-forge
#     llvmlite-0.39.1            |   py39h7d9a04d_0         2.5 MB  conda-forge
#     matplotlib-base-3.6.1      |   py39hf9fd14e_0         7.4 MB  conda-forge
#     mpg123-1.30.2              |       h27087fc_1         512 KB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     nettle-3.8.1               |       hc379101_1         1.1 MB  conda-forge
#     numba-0.56.3               |   py39h61ddf18_0         4.0 MB  conda-forge
#     openh264-2.3.1             |       h27087fc_1         1.5 MB  conda-forge
#     openjpeg-2.5.0             |       h7d73246_1         533 KB  conda-forge
#     openssl-1.1.1q             |       h166bdaf_0         2.1 MB  conda-forge
#     p11-kit-0.24.1             |       hc5aa10d_0         4.5 MB  conda-forge
#     pillow-9.2.0               |   py39hd5dbb17_2        44.9 MB  conda-forge
#     pooch-1.6.0                |     pyhd8ed1ab_0          44 KB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     pyopenssl-22.1.0           |     pyhd8ed1ab_0         122 KB  conda-forge
#     pysocks-1.7.1              |     pyha2e5f31_6          19 KB  conda-forge
#     pysoundfile-0.11.0         |     pyhd8ed1ab_0          25 KB  conda-forge
#     python-3.9.13              |h9a8a25e_0_cpython        26.7 MB  conda-forge
#     requests-2.28.1            |     pyhd8ed1ab_1          53 KB  conda-forge
#     resampy-0.4.2              |     pyhd8ed1ab_0         3.2 MB  conda-forge
#     scikit-learn-1.1.2         |   py39he5e8d7e_0         8.2 MB  conda-forge
#     scipy-1.9.1                |   py39h8ba3f38_0        26.2 MB  conda-forge
#     svt-av1-1.2.1              |       h27087fc_0         3.4 MB  conda-forge
#     threadpoolctl-3.1.0        |     pyh8a188c0_0          18 KB  conda-forge
#     unicodedata2-14.0.0        |   py39hb9d737c_1         498 KB  conda-forge
#     urllib3-1.26.11            |     pyhd8ed1ab_0         102 KB  conda-forge
#     x264-1!164.3095            |       h166bdaf_2         877 KB  conda-forge
#     x265-3.5                   |       h924138e_3         3.2 MB  conda-forge
#     xorg-fixesproto-5.0        |    h7f98852_1002           9 KB  conda-forge
#     xorg-kbproto-1.0.7         |    h7f98852_1002          27 KB  conda-forge
#     xorg-libx11-1.7.2          |       h7f98852_0         941 KB  conda-forge
#     xorg-libxau-1.0.9          |       h7f98852_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     xorg-libxext-1.3.4         |       h7f98852_1          54 KB  conda-forge
#     xorg-libxfixes-5.0.3       |    h7f98852_1004          18 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h7f98852_1002          28 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     zstd-1.5.2                 |       h6239696_4         448 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       209.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   aom                conda-forge/linux-64::aom-3.5.0-h27087fc_0
#   appdirs            conda-forge/noarch::appdirs-1.4.4-pyh9f0ad1d_0
#   audioread          conda-forge/linux-64::audioread-3.0.0-py39hf3d152e_0
#   brotli             conda-forge/linux-64::brotli-1.0.9-h166bdaf_7
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.0.9-h166bdaf_7
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py39hb9d737c_1004
#   certifi            conda-forge/noarch::certifi-2022.9.24-pyhd8ed1ab_0
#   charset-normalizer conda-forge/noarch::charset-normalizer-2.1.1-pyhd8ed1ab_0
#   contourpy          conda-forge/linux-64::contourpy-1.0.5-py39hf939315_0
#   cryptography       conda-forge/linux-64::cryptography-38.0.2-py39hd97740a_0
#   cycler             conda-forge/noarch::cycler-0.11.0-pyhd8ed1ab_0
#   expat              conda-forge/linux-64::expat-2.4.9-h27087fc_0
#   ffmpeg             conda-forge/linux-64::ffmpeg-5.1.2-gpl_he10e716_101
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-hab24e00_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.0-hc2a2eb6_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fonttools          conda-forge/linux-64::fonttools-4.37.4-py39hb9d737c_0
#   freetype           conda-forge/linux-64::freetype-2.12.1-hca18f0e_0
#   gettext            conda-forge/linux-64::gettext-0.21.1-h27087fc_0
#   gmp                conda-forge/linux-64::gmp-6.2.1-h58526e2_0
#   gnutls             conda-forge/linux-64::gnutls-3.7.8-hf3e180e_0
#   idna               conda-forge/noarch::idna-3.4-pyhd8ed1ab_0
#   joblib             conda-forge/noarch::joblib-1.2.0-pyhd8ed1ab_0
#   jpeg               conda-forge/linux-64::jpeg-9e-h166bdaf_2
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.4.4-py39hf939315_0
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   lcms2              conda-forge/linux-64::lcms2-2.12-hddcbb42_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.0.9-h166bdaf_7
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.0.9-h166bdaf_7
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.0.9-h166bdaf_7
#   libdeflate         conda-forge/linux-64::libdeflate-1.14-h166bdaf_0
#   libdrm             conda-forge/linux-64::libdrm-2.4.113-h166bdaf_0
#   libflac            conda-forge/linux-64::libflac-1.4.1-h27087fc_0
#   libidn2            conda-forge/linux-64::libidn2-2.3.3-h166bdaf_0
#   libllvm11          conda-forge/linux-64::libllvm11-11.1.0-he0ac6c6_4
#   libogg             conda-forge/linux-64::libogg-1.3.4-h7f98852_1
#   libopus            conda-forge/linux-64::libopus-1.3.1-h7f98852_1
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.16-h516909a_0
#   libpng             conda-forge/linux-64::libpng-1.6.38-h753d276_0
#   librosa            conda-forge/noarch::librosa-0.9.2-pyhd8ed1ab_0
#   libsndfile         conda-forge/linux-64::libsndfile-1.1.0-h27087fc_0
#   libtasn1           conda-forge/linux-64::libtasn1-4.19.0-h166bdaf_0
#   libtiff            conda-forge/linux-64::libtiff-4.4.0-h55922b4_4
#   libunistring       conda-forge/linux-64::libunistring-0.9.10-h7f98852_0
#   libva              conda-forge/linux-64::libva-2.16.0-h166bdaf_0
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h9c3ff4c_0
#   libvpx             conda-forge/linux-64::libvpx-1.11.0-h9c3ff4c_3
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.2.4-h166bdaf_0
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1004
#   llvmlite           conda-forge/linux-64::llvmlite-0.39.1-py39h7d9a04d_0
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.6.1-py39hf9fd14e_0
#   mpg123             conda-forge/linux-64::mpg123-1.30.2-h27087fc_1
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   nettle             conda-forge/linux-64::nettle-3.8.1-hc379101_1
#   numba              conda-forge/linux-64::numba-0.56.3-py39h61ddf18_0
#   openh264           conda-forge/linux-64::openh264-2.3.1-h27087fc_1
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.0-h7d73246_1
#   p11-kit            conda-forge/linux-64::p11-kit-0.24.1-hc5aa10d_0
#   pillow             conda-forge/linux-64::pillow-9.2.0-py39hd5dbb17_2
#   pooch              conda-forge/noarch::pooch-1.6.0-pyhd8ed1ab_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pyopenssl          conda-forge/noarch::pyopenssl-22.1.0-pyhd8ed1ab_0
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyha2e5f31_6
#   pysoundfile        conda-forge/noarch::pysoundfile-0.11.0-pyhd8ed1ab_0
#   requests           conda-forge/noarch::requests-2.28.1-pyhd8ed1ab_1
#   resampy            conda-forge/noarch::resampy-0.4.2-pyhd8ed1ab_0
#   scikit-learn       conda-forge/linux-64::scikit-learn-1.1.2-py39he5e8d7e_0
#   scipy              conda-forge/linux-64::scipy-1.9.1-py39h8ba3f38_0
#   svt-av1            conda-forge/linux-64::svt-av1-1.2.1-h27087fc_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.1.0-pyh8a188c0_0
#   unicodedata2       conda-forge/linux-64::unicodedata2-14.0.0-py39hb9d737c_1
#   urllib3            conda-forge/noarch::urllib3-1.26.11-pyhd8ed1ab_0
#   x264               conda-forge/linux-64::x264-1!164.3095-h166bdaf_2
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#   xorg-fixesproto    conda-forge/linux-64::xorg-fixesproto-5.0-h7f98852_1002
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.7.2-h7f98852_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h7f98852_1
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-5.0.3-h7f98852_1004
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h7f98852_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#   zstd               conda-forge/linux-64::zstd-1.5.2-h6239696_4
#
# The following packages will be DOWNGRADED:
#
#   openssl                                  3.0.5-h166bdaf_2 --> 1.1.1q-h166bdaf_0
#   python                          3.9.13-h2660328_0_cpython --> 3.9.13-h9a8a25e_0_cpython
#
#
#
# Downloading and Extracting Packages
# cryptography-38.0.2  | 1.5 MB    | ##################################### | 100%
# libogg-1.3.4         | 206 KB    | ##################################### | 100%
# libbrotlienc-1.0.9   | 287 KB    | ##################################### | 100%
# kiwisolver-1.4.4     | 76 KB     | ##################################### | 100%
# urllib3-1.26.11      | 102 KB    | ##################################### | 100%
# expat-2.4.9          | 189 KB    | ##################################### | 100%
# fontconfig-2.14.0    | 318 KB    | ##################################### | 100%
# xorg-libxau-1.0.9    | 13 KB     | ##################################### | 100%
# svt-av1-1.2.1        | 3.4 MB    | ##################################### | 100%
# audioread-3.0.0      | 34 KB     | ##################################### | 100%
# xorg-kbproto-1.0.7   | 27 KB     | ##################################### | 100%
# certifi-2022.9.24    | 155 KB    | ##################################### | 100%
# font-ttf-ubuntu-0.83 | 1.9 MB    | ##################################### | 100%
# threadpoolctl-3.1.0  | 18 KB     | ##################################### | 100%
# font-ttf-dejavu-sans | 388 KB    | ##################################### | 100%
# brotli-1.0.9         | 18 KB     | ##################################### | 100%
# brotlipy-0.7.0       | 342 KB    | ##################################### | 100%
# x265-3.5             | 3.2 MB    | ##################################### | 100%
# p11-kit-0.24.1       | 4.5 MB    | ##################################### | 100%
# xorg-libxdmcp-1.1.3  | 19 KB     | ##################################### | 100%
# libdrm-2.4.113       | 286 KB    | ##################################### | 100%
# lcms2-2.12           | 443 KB    | ##################################### | 100%
# openh264-2.3.1       | 1.5 MB    | ##################################### | 100%
# contourpy-1.0.5      | 234 KB    | ##################################### | 100%
# jpeg-9e              | 269 KB    | ##################################### | 100%
# libdeflate-1.14      | 81 KB     | ##################################### | 100%
# libflac-1.4.1        | 405 KB    | ##################################### | 100%
# zstd-1.5.2           | 448 KB    | ##################################### | 100%
# openssl-1.1.1q       | 2.1 MB    | ##################################### | 100%
# font-ttf-source-code | 684 KB    | ##################################### | 100%
# xorg-xproto-7.0.31   | 73 KB     | ##################################### | 100%
# pysoundfile-0.11.0   | 25 KB     | ##################################### | 100%
# pooch-1.6.0          | 44 KB     | ##################################### | 100%
# libvorbis-1.3.7      | 280 KB    | ##################################### | 100%
# munkres-1.1.4        | 12 KB     | ##################################### | 100%
# libva-2.16.0         | 186 KB    | ##################################### | 100%
# idna-3.4             | 55 KB     | ##################################### | 100%
# xorg-libx11-1.7.2    | 941 KB    | ##################################### | 100%
# libidn2-2.3.3        | 155 KB    | ##################################### | 100%
# resampy-0.4.2        | 3.2 MB    | ##################################### | 100%
# fonts-conda-ecosyste | 4 KB      | ##################################### | 100%
# nettle-3.8.1         | 1.1 MB    | ##################################### | 100%
# pthread-stubs-0.4    | 5 KB      | ##################################### | 100%
# matplotlib-base-3.6. | 7.4 MB    | ##################################### | 100%
# aom-3.5.0            | 2.7 MB    | ##################################### | 100%
# libunistring-0.9.10  | 1.4 MB    | ##################################### | 100%
# libxcb-1.13          | 391 KB    | ##################################### | 100%
# gmp-6.2.1            | 806 KB    | ##################################### | 100%
# joblib-1.2.0         | 205 KB    | ##################################### | 100%
# brotli-bin-1.0.9     | 19 KB     | ##################################### | 100%
# libwebp-base-1.2.4   | 404 KB    | ##################################### | 100%
# mpg123-1.30.2        | 512 KB    | ##################################### | 100%
# libbrotlicommon-1.0. | 65 KB     | ##################################### | 100%
# cycler-0.11.0        | 10 KB     | ##################################### | 100%
# pillow-9.2.0         | 44.9 MB   | ##################################### | 100%
# xorg-libxext-1.3.4   | 54 KB     | ##################################### | 100%
# fonttools-4.37.4     | 1.9 MB    | ##################################### | 100%
# libsndfile-1.1.0     | 370 KB    | ##################################### | 100%
# libpng-1.6.38        | 371 KB    | ##################################### | 100%
# unicodedata2-14.0.0  | 498 KB    | ##################################### | 100%
# numba-0.56.3         | 4.0 MB    | ##################################### | 100%
# libvpx-1.11.0        | 1.1 MB    | ##################################### | 100%
# libllvm11-11.1.0     | 28.8 MB   | ##################################### | 100%
# scikit-learn-1.1.2   | 8.2 MB    | ##################################### | 100%
# pyopenssl-22.1.0     | 122 KB    | ##################################### | 100%
# libtiff-4.4.0        | 651 KB    | ##################################### | 100%
# libtasn1-4.19.0      | 114 KB    | ##################################### | 100%
# openjpeg-2.5.0       | 533 KB    | ##################################### | 100%
# font-ttf-inconsolata | 94 KB     | ##################################### | 100%
# xorg-libxfixes-5.0.3 | 18 KB     | ##################################### | 100%
# python-3.9.13        | 26.7 MB   | ##################################### | 100%
# libpciaccess-0.16    | 37 KB     | ##################################### | 100%
# gnutls-3.7.8         | 2.2 MB    | ##################################### | 100%
# pysocks-1.7.1        | 19 KB     | ##################################### | 100%
# ffmpeg-5.1.2         | 10.4 MB   | ##################################### | 100%
# librosa-0.9.2        | 156 KB    | ##################################### | 100%
# requests-2.28.1      | 53 KB     | ##################################### | 100%
# scipy-1.9.1          | 26.2 MB   | ##################################### | 100%
# gettext-0.21.1       | 4.1 MB    | ##################################### | 100%
# llvmlite-0.39.1      | 2.5 MB    | ##################################### | 100%
# freetype-2.12.1      | 884 KB    | ##################################### | 100%
# fonts-conda-forge-1  | 4 KB      | ##################################### | 100%
# xorg-fixesproto-5.0  | 9 KB      | ##################################### | 100%
# x264-1!164.3095      | 877 KB    | ##################################### | 100%
# libbrotlidec-1.0.9   | 33 KB     | ##################################### | 100%
# charset-normalizer-2 | 36 KB     | ##################################### | 100%
# xorg-xextproto-7.3.0 | 28 KB     | ##################################### | 100%
# libopus-1.3.1        | 255 KB    | ##################################### | 100%
# appdirs-1.4.4        | 13 KB     | ##################################### | 100%
# lame-3.100           | 496 KB    | ##################################### | 100%
# lerc-4.0.0           | 275 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Convert to log mel

# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np

# %%
# !mkdir log_mel_OpenMIC

# %%
files = ['openmic-2018/audio/000/000046_3840.ogg'] # we can make a list comprehension of all files needed
save_path = "log_mel_OpenMIC/"

# %%
for file in files:
  scale, sampling_rate = librosa.load(file)
  # filter_banks = librosa.filters.mel(n_fft=2048, sr=22050, n_mels=10)
  mel_spectrogram = librosa.feature.melspectrogram(scale, sr=sampling_rate, n_fft=2048, hop_length=512, n_mels=128)
  log_mel_spectrogram = librosa.power_to_db(mel_spectrogram)
  img = librosa.display.specshow(log_mel_spectrogram, x_axis="time", y_axis="mel", sr=sampling_rate)
  # print(log_mel_spectrogram.shape)
  # print(type(log_mel_spectrogram))

  plt.savefig((save_path + file.split('/')[-1]).replace(".ogg", ".png"))
  # CURRENTLY saves with just filename without the 000 folder structure as the
  # first 3 numbers of filename indicate the folder anyway
# Out:
# /tmp/ipykernel_1064/124365548.py:4: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.15737659 -0.15117157
#  -0.1723783 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spectrogram = librosa.feature.melspectrogram(scale, sr=sampling_rate, n_fft=2048, hop_length=512, n_mels=128)
