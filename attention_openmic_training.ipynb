# %% [markdown]
# <a href="https://colab.research.google.com/github/aritejhg/ESP3201-Instrument-indentification/blob/main/attention_openmic_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## download repo and dataset

# %%
# !git clone https://github.com/SiddGururani/AttentionMIC.git
# Out:
# Cloning into 'AttentionMIC'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 17 (delta 1), reused 1 (delta 1), pack-reused 13
# Unpacking objects: 100% (17/17), done.

# %%
# !wget https://zenodo.org/record/1432913/files/openmic-2018-v1.0.0.tgz 
# NOT NEEDED as we can download just the npz straight

# %%
# !pip install gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (4.4.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown) (3.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.64.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.7.1)

# %% [markdown]
# Test.npz : https://drive.google.com/file/d/1mf0UDhzN9cYtzqXuqbNSPS8_JuRt6MAA/view?usp=share_link
#
# Train.npz : https://drive.google.com/file/d/1bUwrN2iLYJBPsVsm3S_4PnITYrJMDDC1/view?usp=share_link
#
# split: https://drive.google.com/file/d/1di3IrCHeKsLlpMJwOYDDYTNOot4WVxJD/view?usp=share_link

# %%
# %cd AttentionMIC/data

# !gdown https://drive.google.com/uc?id=1mf0UDhzN9cYtzqXuqbNSPS8_JuRt6MAA
# !gdown https://drive.google.com/uc?id=1bUwrN2iLYJBPsVsm3S_4PnITYrJMDDC1
# !gdown https://drive.google.com/uc?id=1di3IrCHeKsLlpMJwOYDDYTNOot4WVxJD
# Out:
# /content/AttentionMIC/data
# Downloading...
# From: https://drive.google.com/uc?id=1mf0UDhzN9cYtzqXuqbNSPS8_JuRt6MAA
# To: /content/AttentionMIC/data/test.npz
# 100% 53.1M/53.1M [00:00<00:00, 132MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1bUwrN2iLYJBPsVsm3S_4PnITYrJMDDC1
# To: /content/AttentionMIC/data/train.npz
# 100% 156M/156M [00:00<00:00, 165MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1di3IrCHeKsLlpMJwOYDDYTNOot4WVxJD
# To: /content/AttentionMIC/data/train_val.split
# 100% 120k/120k [00:00<00:00, 89.1MB/s]

# %%
# %cd ..
# Out:
# /content/AttentionMIC

# %% [markdown]
# ## train hehe

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorboardX
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 5.0 MB/s
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.21.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (1.15.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5.1

# %%
# %cd AttentionMIC
# !python train_attention_multiruns.py --num_epochs 20 --batch_size 128 --id decisionlevelsingleattention_128_3_0.6_lr0.0005_noannealing_res --loss_type BCE --lr 0.0005 --dropout_rate 0.6 --hidden_size 128 --emb_layers 3 --log_dir /content/AttentionMIC --model_type attention
# Out:
# Streaming output truncated to the last 5000 lines.
#          0.0       0.89      0.76      0.82       324
#          1.0       0.78      0.90      0.83       305
#
#     accuracy                           0.83       629
#    macro avg       0.83      0.83      0.82       629
# weighted avg       0.83      0.83      0.82       629
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.88      0.92       112
#          1.0       0.95      0.98      0.97       268
#
#     accuracy                           0.95       380
#    macro avg       0.95      0.93      0.94       380
# weighted avg       0.95      0.95      0.95       380
#
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.87      0.87       492
#          1.0       0.72      0.75      0.74       228
#
#     accuracy                           0.83       720
#    macro avg       0.80      0.81      0.80       720
# weighted avg       0.83      0.83      0.83       720
#
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.80      0.82       467
#          1.0       0.72      0.77      0.74       318
#
#     accuracy                           0.79       785
#    macro avg       0.78      0.78      0.78       785
# weighted avg       0.79      0.79      0.79       785
#
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.83      0.84       408
#          1.0       0.63      0.66      0.65       182
#
#     accuracy                           0.78       590
#    macro avg       0.74      0.75      0.74       590
# weighted avg       0.78      0.78      0.78       590
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.67      0.78       237
#          1.0       0.83      0.98      0.90       394
#
#     accuracy                           0.86       631
#    macro avg       0.89      0.82      0.84       631
# weighted avg       0.88      0.86      0.86       631
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.87      0.92       150
#          1.0       0.92      0.98      0.95       224
#
#     accuracy                           0.94       374
#    macro avg       0.94      0.92      0.93       374
# weighted avg       0.94      0.94      0.94       374
#
# Test Prediction Loss:  0.3740065395832062
# Test Avg F1-score weighted:  0.8320059762050466
# Test Avg F1-score macro:  0.7977647024926668
# Test Class F1-score weighted:  [0.79209508 0.79094895 0.79118215 0.82278596 0.72064799 0.93433659
#  0.90821867 0.70552791 0.96077911 0.79151199 0.78595649 0.72646983
#  0.94582784 0.82450264 0.95210268 0.83003143 0.78698369 0.77940669
#  0.85567621 0.93512764]
# Test Class F1-score macro:  [0.68321314 0.75052063 0.73982544 0.82266156 0.52926077 0.92293513
#  0.89634586 0.65774452 0.95630928 0.78996766 0.75790693 0.64479341
#  0.93583797 0.82474671 0.94178922 0.80466501 0.78023516 0.74323197
#  0.84141927 0.93188441]
#   0% 0/40 [00:00<?, ?it/s]/content/AttentionMIC/utils.py:117: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   loss = criterion(outputs[Y_mask], Y_true[Y_mask])
# 100% 40/40 [00:00<00:00, 118.03it/s]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.89      0.87       423
#          1.0       0.53      0.46      0.49       115
#
#     accuracy                           0.80       538
#    macro avg       0.69      0.67      0.68       538
# weighted avg       0.79      0.80      0.79       538
#
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.83      0.85       338
#          1.0       0.63      0.68      0.65       140
#
#     accuracy                           0.79       478
#    macro avg       0.75      0.76      0.75       478
# weighted avg       0.79      0.79      0.79       478
#
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.89      0.86       329
#          1.0       0.68      0.57      0.62       134
#
#     accuracy                           0.80       463
#    macro avg       0.76      0.73      0.74       463
# weighted avg       0.79      0.80      0.79       463
#
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.78      0.82       259
#          1.0       0.78      0.87      0.82       226
#
#     accuracy                           0.82       485
#    macro avg       0.83      0.83      0.82       485
# weighted avg       0.83      0.82      0.82       485
#
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.94      0.86       503
#          1.0       0.38      0.13      0.19       137
#
#     accuracy                           0.77       640
#    macro avg       0.59      0.54      0.53       640
# weighted avg       0.71      0.77      0.72       640
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.83      0.89       139
#          1.0       0.92      0.99      0.95       297
#
#     accuracy                           0.94       436
#    macro avg       0.95      0.91      0.92       436
# weighted avg       0.94      0.94      0.93       436
#
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.79      0.86       146
#          1.0       0.90      0.97      0.93       278
#
#     accuracy                           0.91       424
#    macro avg       0.92      0.88      0.90       424
# weighted avg       0.91      0.91      0.91       424
#
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.78      0.78       387
#          1.0       0.53      0.54      0.53       175
#
#     accuracy                           0.70       562
#    macro avg       0.66      0.66      0.66       562
# weighted avg       0.71      0.70      0.71       562
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.94       150
#          1.0       0.96      0.98      0.97       286
#
#     accuracy                           0.96       436
#    macro avg       0.96      0.95      0.96       436
# weighted avg       0.96      0.96      0.96       436
#
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.76      0.80       267
#          1.0       0.73      0.82      0.78       211
#
#     accuracy                           0.79       478
#    macro avg       0.79      0.79      0.79       478
# weighted avg       0.80      0.79      0.79       478
#
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.78      0.83       434
#          1.0       0.61      0.78      0.68       193
#
#     accuracy                           0.78       627
#    macro avg       0.75      0.78      0.76       627
# weighted avg       0.80      0.78      0.79       627
#
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.88      0.83       310
#          1.0       0.56      0.39      0.46       121
#
#     accuracy                           0.74       431
#    macro avg       0.67      0.63      0.64       431
# weighted avg       0.72      0.74      0.73       431
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.85      0.91       130
#          1.0       0.93      0.99      0.96       285
#
#     accuracy                           0.95       415
#    macro avg       0.96      0.92      0.94       415
# weighted avg       0.95      0.95      0.95       415
#
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.76      0.82       324
#          1.0       0.78      0.90      0.83       305
#
#     accuracy                           0.83       629
#    macro avg       0.83      0.83      0.82       629
# weighted avg       0.83      0.83      0.82       629
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.88      0.92       112
#          1.0       0.95      0.98      0.97       268
#
#     accuracy                           0.95       380
#    macro avg       0.95      0.93      0.94       380
# weighted avg       0.95      0.95      0.95       380
#
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.87      0.87       492
#          1.0       0.72      0.75      0.74       228
#
#     accuracy                           0.83       720
#    macro avg       0.80      0.81      0.80       720
# weighted avg       0.83      0.83      0.83       720
#
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.80      0.82       467
#          1.0       0.72      0.77      0.74       318
#
#     accuracy                           0.79       785
#    macro avg       0.78      0.78      0.78       785
# weighted avg       0.79      0.79      0.79       785
#
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.83      0.84       408
#          1.0       0.63      0.66      0.65       182
#
#     accuracy                           0.78       590
#    macro avg       0.74      0.75      0.74       590
# weighted avg       0.78      0.78      0.78       590
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.67      0.78       237
#          1.0       0.83      0.98      0.90       394
#
#     accuracy                           0.86       631
#    macro avg       0.89      0.82      0.84       631
# weighted avg       0.88      0.86      0.86       631
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.87      0.92       150
#          1.0       0.92      0.98      0.95       224
#
#     accuracy                           0.94       374
#    macro avg       0.94      0.92      0.93       374
# weighted avg       0.94      0.94      0.94       374
#
# Test Prediction Loss:  0.3740065395832062
# Test Avg F1-score weighted:  0.8320059762050466
# Test Avg F1-score macro:  0.7977647024926668
# Test Class F1-score weighted:  [0.79209508 0.79094895 0.79118215 0.82278596 0.72064799 0.93433659
#  0.90821867 0.70552791 0.96077911 0.79151199 0.78595649 0.72646983
#  0.94582784 0.82450264 0.95210268 0.83003143 0.78698369 0.77940669
#  0.85567621 0.93512764]
# Test Class F1-score macro:  [0.68321314 0.75052063 0.73982544 0.82266156 0.52926077 0.92293513
#  0.89634586 0.65774452 0.95630928 0.78996766 0.75790693 0.64479341
#  0.93583797 0.82474671 0.94178922 0.80466501 0.78023516 0.74323197
#  0.84141927 0.93188441]
# 55336
# Dumping logs in /content/AttentionMIC/attention/decisionlevelsingleattention_128_3_0.6_lr0.0005_noannealing_res_seed_239
#   0% 0/20 [00:00<?, ?it/s]
#   0% 0/100 [00:00<?, ?it/s]/content/AttentionMIC/utils.py:71: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   loss = criterion(outputs[Y_mask], Y_true[Y_mask])
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py:175: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
#   9% 9/100 [00:00<00:01, 82.50it/s]
#  18% 18/100 [00:00<00:01, 78.09it/s]
#  26% 26/100 [00:00<00:01, 73.34it/s]
#  35% 35/100 [00:00<00:00, 77.68it/s]
#  43% 43/100 [00:00<00:00, 76.50it/s]
#  52% 52/100 [00:00<00:00, 78.46it/s]
#  60% 60/100 [00:00<00:00, 77.54it/s]
#  69% 69/100 [00:00<00:00, 78.65it/s]
#  78% 78/100 [00:00<00:00, 79.64it/s]
#  86% 86/100 [00:01<00:00, 77.00it/s]
# 100% 100/100 [00:01<00:00, 78.56it/s]
#
#   0% 0/18 [00:00<?, ?it/s]/content/AttentionMIC/utils.py:117: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   loss = criterion(outputs[Y_mask], Y_true[Y_mask])
#
# 100% 18/18 [00:00<00:00, 108.62it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.77      1.00      0.87       189
#          1.0       0.00      0.00      0.00        55
#
#     accuracy                           0.77       244
#    macro avg       0.39      0.50      0.44       244
# weighted avg       0.60      0.77      0.68       244
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.98      0.81       170
#          1.0       0.75      0.10      0.18        86
#
#     accuracy                           0.69       256
#    macro avg       0.72      0.54      0.50       256
# weighted avg       0.71      0.69      0.60       256
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83       163
#          1.0       0.00      0.00      0.00        68
#
#     accuracy                           0.71       231
#    macro avg       0.35      0.50      0.41       231
# weighted avg       0.50      0.71      0.58       231
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.96      0.77       126
#          1.0       0.64      0.12      0.20        78
#
#     accuracy                           0.64       204
#    macro avg       0.64      0.54      0.48       204
# weighted avg       0.64      0.64      0.55       204
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.79      1.00      0.88       199
#          1.0       0.00      0.00      0.00        54
#
#     accuracy                           0.79       253
#    macro avg       0.39      0.50      0.44       253
# weighted avg       0.62      0.79      0.69       253
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.36      0.53        66
#          1.0       0.73      0.99      0.84       114
#
#     accuracy                           0.76       180
#    macro avg       0.84      0.68      0.68       180
# weighted avg       0.81      0.76      0.73       180
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.22      0.36        77
#          1.0       0.68      1.00      0.81       125
#
#     accuracy                           0.70       202
#    macro avg       0.84      0.61      0.58       202
# weighted avg       0.80      0.70      0.64       202
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.66      1.00      0.80       165
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.66       249
#    macro avg       0.33      0.50      0.40       249
# weighted avg       0.44      0.66      0.53       249
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.09      0.16        58
#          1.0       0.69      1.00      0.81       116
#
#     accuracy                           0.70       174
#    macro avg       0.84      0.54      0.49       174
# weighted avg       0.79      0.70      0.60       174
#
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.98      0.80       114
#          1.0       0.80      0.13      0.22        62
#
#     accuracy                           0.68       176
#    macro avg       0.74      0.56      0.51       176
# weighted avg       0.72      0.68      0.60       176
#
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.93      0.78       162
#          1.0       0.59      0.18      0.27        91
#
#     accuracy                           0.66       253
#    macro avg       0.63      0.55      0.52       253
# weighted avg       0.64      0.66      0.60       253
#
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.97      0.78       150
#          1.0       0.69      0.10      0.18        89
#
#     accuracy                           0.65       239
#    macro avg       0.67      0.54      0.48       239
# weighted avg       0.66      0.65      0.55       239
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.38      0.54        56
#          1.0       0.77      0.99      0.87       119
#
#     accuracy                           0.79       175
#    macro avg       0.86      0.68      0.70       175
# weighted avg       0.83      0.79      0.76       175
#
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.37      0.44       135
#          1.0       0.53      0.71      0.61       136
#
#     accuracy                           0.54       271
#    macro avg       0.54      0.54      0.53       271
# weighted avg       0.54      0.54      0.53       271
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.08      0.15        63
#          1.0       0.69      1.00      0.82       130
#
#     accuracy                           0.70       193
#    macro avg       0.85      0.54      0.48       193
# weighted avg       0.79      0.70      0.60       193
#
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.99      0.82       208
#          1.0       0.00      0.00      0.00        90
#
#     accuracy                           0.69       298
#    macro avg       0.35      0.50      0.41       298
# weighted avg       0.49      0.69      0.57       298
#
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.93      0.75       193
#          1.0       0.41      0.08      0.13       119
#
#     accuracy                           0.61       312
#    macro avg       0.51      0.50      0.44       312
# weighted avg       0.54      0.61      0.51       312
#
#               precision    recall  f1-score   support
#
#          0.0       0.69      1.00      0.82       183
#          1.0       1.00      0.01      0.02        83
#
#     accuracy                           0.69       266
#    macro avg       0.85      0.51      0.42       266
# weighted avg       0.79      0.69      0.57       266
#
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.23      0.36        97
#          1.0       0.57      0.97      0.72       104
#
#     accuracy                           0.61       201
#    macro avg       0.73      0.60      0.54       201
# weighted avg       0.72      0.61      0.55       201
#
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.31      0.47        64
#          1.0       0.69      0.98      0.81        99
#
#     accuracy                           0.72       163
#    macro avg       0.80      0.65      0.64       163
# weighted avg       0.77      0.72      0.67       163
#
#   5% 1/20 [00:01<00:30,  1.60s/it]
#   0% 0/100 [00:00<?, ?it/s]/content/AttentionMIC/utils.py:71: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   loss = criterion(outputs[Y_mask], Y_true[Y_mask])
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py:175: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
#   9% 9/100 [00:00<00:01, 83.48it/s]
#  18% 18/100 [00:00<00:01, 77.12it/s]
#  27% 27/100 [00:00<00:00, 79.70it/s]
#  35% 35/100 [00:00<00:00, 78.23it/s]
#  44% 44/100 [00:00<00:00, 80.79it/s]
#  53% 53/100 [00:00<00:00, 77.85it/s]
#  61% 61/100 [00:00<00:00, 78.04it/s]
#  70% 70/100 [00:00<00:00, 80.48it/s]
#  79% 79/100 [00:01<00:00, 78.49it/s]
#  88% 88/100 [00:01<00:00, 80.20it/s]
# 100% 100/100 [00:01<00:00, 79.71it/s]
#
#   0% 0/18 [00:00<?, ?it/s]/content/AttentionMIC/utils.py:117: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   loss = criterion(outputs[Y_mask], Y_true[Y_mask])
#
# 100% 18/18 [00:00<00:00, 131.51it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.77      1.00      0.87       189
#          1.0       0.00      0.00      0.00        55
#
#     accuracy                           0.77       244
#    macro avg       0.39      0.50      0.44       244
# weighted avg       0.60      0.77      0.68       244
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.98      0.83       170
#          1.0       0.84      0.24      0.38        86
#
#     accuracy                           0.73       256
#    macro avg       0.78      0.61      0.60       256
# weighted avg       0.76      0.73      0.68       256
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83       163
#          1.0       0.00      0.00      0.00        68
#
#     accuracy                           0.71       231
#    macro avg       0.35      0.50      0.41       231
# weighted avg       0.50      0.71      0.58       231
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.83      0.78       126
#          1.0       0.65      0.50      0.57        78
#
#     accuracy                           0.71       204
#    macro avg       0.69      0.67      0.67       204
# weighted avg       0.70      0.71      0.70       204
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.79      1.00      0.88       199
#          1.0       0.00      0.00      0.00        54
#
#     accuracy                           0.79       253
#    macro avg       0.39      0.50      0.44       253
# weighted avg       0.62      0.79      0.69       253
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.68      0.80        66
#          1.0       0.84      0.98      0.91       114
#
#     accuracy                           0.87       180
#    macro avg       0.90      0.83      0.85       180
# weighted avg       0.88      0.87      0.87       180
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.44      0.61        77
#          1.0       0.74      1.00      0.85       125
#
#     accuracy                           0.79       202
#    macro avg       0.87      0.72      0.73       202
# weighted avg       0.84      0.79      0.76       202
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.66      1.00      0.80       165
#          1.0       0.00      0.00      0.00        84
#
#     accuracy                           0.66       249
#    macro avg       0.33      0.50      0.40       249
# weighted avg       0.44      0.66      0.53       249
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.26      0.41        58
#          1.0       0.73      1.00      0.84       116
#
#     accuracy                           0.75       174
#    macro avg       0.86      0.63      0.63       174
# weighted avg       0.82      0.75      0.70       174
#
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.96      0.82       114
#          1.0       0.80      0.32      0.46        62
#
#     accuracy                           0.73       176
#    macro avg       0.76      0.64      0.64       176
# weighted avg       0.75      0.73      0.69       176
#
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.90      0.78       162
#          1.0       0.61      0.30      0.40        91
#
#     accuracy                           0.68       253
#    macro avg       0.65      0.60      0.59       253
# weighted avg       0.66      0.68      0.64       253
#
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.98      0.86       150
#          1.0       0.94      0.52      0.67        89
#
#     accuracy                           0.81       239
#    macro avg       0.86      0.75      0.77       239
# weighted avg       0.84      0.81      0.79       239
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.66      0.80        56
#          1.0       0.86      1.00      0.93       119
#
#     accuracy                           0.89       175
#    macro avg       0.93      0.83      0.86       175
# weighted avg       0.91      0.89      0.88       175
#
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.35      0.49       135
#          1.0       0.59      0.92      0.72       136
#
#     accuracy                           0.63       271
#    macro avg       0.70      0.63      0.60       271
# weighted avg       0.70      0.63      0.60       271
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.40      0.56        63
#          1.0       0.77      0.99      0.87       130
#
#     accuracy                           0.80       193
#    macro avg       0.87      0.69      0.72       193
# weighted avg       0.83      0.80      0.77       193
#
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.99      0.82       208
#          1.0       0.62      0.06      0.10        90
#
#     accuracy                           0.70       298
#    macro avg       0.67      0.52      0.46       298
# weighted avg       0.68      0.70      0.61       298
#
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.89      0.77       193
#          1.0       0.63      0.30      0.41       119
#
#     accuracy                           0.67       312
#    macro avg       0.65      0.60      0.59       312
# weighted avg       0.66      0.67      0.63       312
#
#               precision    recall  f1-score   support
#
#          0.0       0.70      1.00      0.82       183
#          1.0       1.00      0.04      0.07        83
#
#     accuracy                           0.70       266
#    macro avg       0.85      0.52      0.45       266
# weighted avg       0.79      0.70      0.59       266
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.37      0.53        97
#          1.0       0.63      0.98      0.76       104
#
#     accuracy                           0.69       201
#    macro avg       0.79      0.68      0.65       201
# weighted avg       0.78      0.69      0.65       201
#
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.66      0.77        64
#          1.0       0.81      0.97      0.88        99
#
#     accuracy                           0.85       163
#    macro avg       0.87      0.81      0.83       163
# weighted avg       0.86      0.85      0.84       163
#
#  10% 2/20 [00:03<00:28,  1.57s/it]
#   0% 0/100 [00:00<?, ?it/s]/content/AttentionMIC/utils.py:71: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   loss = criterion(outputs[Y_mask], Y_true[Y_mask])
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py:175: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
#   9% 9/100 [00:00<00:01, 83.00it/s]
#  18% 18/100 [00:00<00:01, 73.10it/s]
#  26% 26/100 [00:00<00:00, 75.62it/s]
#  34% 34/100 [00:00<00:00, 75.02it/s]
#  42% 42/100 [00:00<00:00, 74.37it/s]
#  51% 51/100 [00:00<00:00, 76.54it/s]
#  59% 59/100 [00:00<00:00, 74.76it/s]
#  68% 68/100 [00:00<00:00, 77.76it/s]
#  76% 76/100 [00:01<00:00, 75.91it/s]
#  85% 85/100 [00:01<00:00, 77.39it/s]
# 100% 100/100 [00:01<00:00, 76.72it/s]
#
#   0% 0/18 [00:00<?, ?it/s]/content/AttentionMIC/utils.py:117: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   loss = criterion(outputs[Y_mask], Y_true[Y_mask])
#
# 100% 18/18 [00:00<00:00, 129.91it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.77      1.00      0.87       189
#          1.0       0.00      0.00      0.00        55
#
#     accuracy                           0.77       244
#    macro avg       0.39      0.50      0.44       244
# weighted avg       0.60      0.77      0.68       244
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.91      0.87       170
#          1.0       0.78      0.62      0.69        86
#
#     accuracy                           0.81       256
#    macro avg       0.80      0.76      0.78       256
# weighted avg       0.81      0.81      0.81       256
#
#               precision    recall  f1-score   support
#
#          0.0       0.72      1.00      0.84       163
#          1.0       1.00      0.07      0.14        68
#
#     accuracy                           0.73       231
#    macro avg       0.86      0.54      0.49       231
# weighted avg       0.80      0.73      0.63       231
#
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.78      0.76       126
#          1.0       0.61      0.55      0.58        78
#
#     accuracy                           0.69       204
#    macro avg       0.67      0.66      0.67       204
# weighted avg       0.69      0.69      0.69       204
#
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.99      0.88       199
#          1.0       0.50      0.02      0.04        54
#
#     accuracy                           0.79       253
#    macro avg       0.64      0.51      0.46       253
# weighted avg       0.73      0.79      0.70       253
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.79      0.86        66
#          1.0       0.89      0.97      0.93       114
#
#     accuracy                           0.91       180
#    macro avg       0.92      0.88      0.89       180
# weighted avg       0.91      0.91      0.90       180
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.61      0.76        77
#          1.0       0.81      1.00      0.89       125
#
#     accuracy                           0.85       202
#    macro avg       0.90      0.81      0.83       202
# weighted avg       0.88      0.85      0.84       202
#
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.97      0.80       165
#          1.0       0.58      0.08      0.15        84
#
#     accuracy                           0.67       249
#    macro avg       0.63      0.53      0.47       249
# weighted avg       0.64      0.67      0.58       249
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.33      0.49        58
#          1.0       0.75      1.00      0.86       116
#
#     accuracy                           0.78       174
#    macro avg       0.87      0.66      0.67       174
# weighted avg       0.83      0.78      0.74       174
#
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.89      0.82       114
#          1.0       0.71      0.48      0.58        62
#
#     accuracy                           0.75       176
#    macro avg       0.74      0.69      0.70       176
# weighted avg       0.74      0.75      0.74       176
#
#               precision    recall  f1-score   support
#
# ...
#
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.84      0.89       150
#          1.0       0.90      0.96      0.93       224
#
#     accuracy                           0.91       374
#    macro avg       0.92      0.90      0.91       374
# weighted avg       0.92      0.91      0.91       374
#
# Test Prediction Loss:  0.4102494418621063
# Test Avg F1-score weighted:  0.8249831407448338
# Test Avg F1-score macro:  0.7893232492917476
# Test Class F1-score weighted:  [0.78342599 0.76754163 0.78662092 0.80215982 0.7206515  0.94144599
#  0.90799918 0.66883239 0.9678381  0.7617234  0.76991788 0.72945941
#  0.94057037 0.8212403  0.95210268 0.83055556 0.80121626 0.78335581
#  0.84950211 0.91350352]
# Test Class F1-score macro:  [0.65253948 0.72172322 0.73623502 0.80135163 0.51838898 0.93134593
#  0.89592538 0.61807403 0.96431495 0.76148957 0.73867937 0.6633538
#  0.92930956 0.82150603 0.94178922 0.8042362  0.79259036 0.74858868
#  0.83584436 0.90917921]
#   0% 0/40 [00:00<?, ?it/s]/content/AttentionMIC/utils.py:117: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   loss = criterion(outputs[Y_mask], Y_true[Y_mask])
# 100% 40/40 [00:00<00:00, 124.21it/s]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.92      0.88       423
#          1.0       0.56      0.38      0.46       115
#
#     accuracy                           0.80       538
#    macro avg       0.70      0.65      0.67       538
# weighted avg       0.79      0.80      0.79       538
#
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.81      0.83       338
#          1.0       0.59      0.66      0.62       140
#
#     accuracy                           0.76       478
#    macro avg       0.72      0.73      0.72       478
# weighted avg       0.77      0.76      0.77       478
#
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.84      0.85       329
#          1.0       0.64      0.69      0.66       134
#
#     accuracy                           0.80       463
#    macro avg       0.75      0.76      0.76       463
# weighted avg       0.80      0.80      0.80       463
#
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.75      0.80       259
#          1.0       0.75      0.86      0.80       226
#
#     accuracy                           0.80       485
#    macro avg       0.81      0.81      0.80       485
# weighted avg       0.81      0.80      0.80       485
#
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.97      0.87       503
#          1.0       0.47      0.11      0.18       137
#
#     accuracy                           0.78       640
#    macro avg       0.63      0.54      0.53       640
# weighted avg       0.73      0.78      0.73       640
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.83      0.90       139
#          1.0       0.93      0.99      0.96       297
#
#     accuracy                           0.94       436
#    macro avg       0.95      0.91      0.93       436
# weighted avg       0.94      0.94      0.94       436
#
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.79      0.86       146
#          1.0       0.90      0.97      0.93       278
#
#     accuracy                           0.91       424
#    macro avg       0.92      0.88      0.89       424
# weighted avg       0.91      0.91      0.91       424
#
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.75      0.77       387
#          1.0       0.49      0.54      0.51       175
#
#     accuracy                           0.68       562
#    macro avg       0.64      0.64      0.64       562
# weighted avg       0.69      0.68      0.69       562
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95       150
#          1.0       0.97      0.98      0.97       286
#
#     accuracy                           0.97       436
#    macro avg       0.96      0.96      0.96       436
# weighted avg       0.97      0.97      0.97       436
#
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.73      0.79       267
#          1.0       0.71      0.84      0.77       211
#
#     accuracy                           0.78       478
#    macro avg       0.78      0.78      0.78       478
# weighted avg       0.79      0.78      0.78       478
#
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.77      0.82       434
#          1.0       0.59      0.77      0.67       193
#
#     accuracy                           0.77       627
#    macro avg       0.74      0.77      0.74       627
# weighted avg       0.79      0.77      0.77       627
#
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.87      0.83       310
#          1.0       0.55      0.41      0.47       121
#
#     accuracy                           0.74       431
#    macro avg       0.67      0.64      0.65       431
# weighted avg       0.72      0.74      0.73       431
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.83      0.90       130
#          1.0       0.93      1.00      0.96       285
#
#     accuracy                           0.94       415
#    macro avg       0.96      0.91      0.93       415
# weighted avg       0.95      0.94      0.94       415
#
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.73      0.80       324
#          1.0       0.76      0.91      0.83       305
#
#     accuracy                           0.82       629
#    macro avg       0.83      0.82      0.82       629
# weighted avg       0.83      0.82      0.82       629
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.88      0.92       112
#          1.0       0.95      0.98      0.97       268
#
#     accuracy                           0.95       380
#    macro avg       0.95      0.93      0.94       380
# weighted avg       0.95      0.95      0.95       380
#
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.84      0.87       492
#          1.0       0.69      0.80      0.74       228
#
#     accuracy                           0.82       720
#    macro avg       0.80      0.82      0.81       720
# weighted avg       0.83      0.82      0.83       720
#
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.80      0.82       467
#          1.0       0.73      0.78      0.75       318
#
#     accuracy                           0.79       785
#    macro avg       0.78      0.79      0.79       785
# weighted avg       0.80      0.79      0.79       785
#
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.81      0.83       408
#          1.0       0.62      0.70      0.66       182
#
#     accuracy                           0.78       590
#    macro avg       0.74      0.76      0.75       590
# weighted avg       0.79      0.78      0.78       590
#
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.68      0.78       237
#          1.0       0.83      0.96      0.89       394
#
#     accuracy                           0.85       631
#    macro avg       0.87      0.82      0.83       631
# weighted avg       0.86      0.85      0.85       631
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.85      0.91       150
#          1.0       0.91      0.98      0.94       224
#
#     accuracy                           0.93       374
#    macro avg       0.94      0.92      0.93       374
# weighted avg       0.93      0.93      0.93       374
#
# Test Prediction Loss:  0.3956041634082794
# Test Avg F1-score weighted:  0.8274600800245893
# Test Avg F1-score macro:  0.7930500936114075
# Test Class F1-score weighted:  [0.79021398 0.76731484 0.79906121 0.80208878 0.72560615 0.93676167
#  0.9059135  0.68685424 0.96551232 0.77890748 0.77386664 0.72774962
#  0.94312812 0.8160751  0.95210268 0.82793985 0.793428   0.7798008
#  0.84727137 0.92960524]
# Test Class F1-score macro:  [0.66852288 0.72402835 0.75840439 0.80206101 0.52620114 0.92585361
#  0.89383054 0.63941635 0.961704   0.77792777 0.74494015 0.64969521
#  0.9324243  0.81642773 0.94178922 0.80511278 0.787043   0.74656357
#  0.83305216 0.92600371]
#   0% 0/40 [00:00<?, ?it/s]/content/AttentionMIC/utils.py:117: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:27.)
#   loss = criterion(outputs[Y_mask], Y_true[Y_mask])
# 100% 40/40 [00:00<00:00, 121.74it/s]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.92      0.88       423
#          1.0       0.56      0.38      0.46       115
#
#     accuracy                           0.80       538
#    macro avg       0.70      0.65      0.67       538
# weighted avg       0.79      0.80      0.79       538
#
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.81      0.83       338
#          1.0       0.59      0.66      0.62       140
#
#     accuracy                           0.76       478
#    macro avg       0.72      0.73      0.72       478
# weighted avg       0.77      0.76      0.77       478
#
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.84      0.85       329
#          1.0       0.64      0.69      0.66       134
#
#     accuracy                           0.80       463
#    macro avg       0.75      0.76      0.76       463
# weighted avg       0.80      0.80      0.80       463
#
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.75      0.80       259
#          1.0       0.75      0.86      0.80       226
#
#     accuracy                           0.80       485
#    macro avg       0.81      0.81      0.80       485
# weighted avg       0.81      0.80      0.80       485
#
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.97      0.87       503
#          1.0       0.47      0.11      0.18       137
#
#     accuracy                           0.78       640
#    macro avg       0.63      0.54      0.53       640
# weighted avg       0.73      0.78      0.73       640
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.83      0.90       139
#          1.0       0.93      0.99      0.96       297
#
#     accuracy                           0.94       436
#    macro avg       0.95      0.91      0.93       436
# weighted avg       0.94      0.94      0.94       436
#
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.79      0.86       146
#          1.0       0.90      0.97      0.93       278
#
#     accuracy                           0.91       424
#    macro avg       0.92      0.88      0.89       424
# weighted avg       0.91      0.91      0.91       424
#
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.75      0.77       387
#          1.0       0.49      0.54      0.51       175
#
#     accuracy                           0.68       562
#    macro avg       0.64      0.64      0.64       562
# weighted avg       0.69      0.68      0.69       562
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.94      0.95       150
#          1.0       0.97      0.98      0.97       286
#
#     accuracy                           0.97       436
#    macro avg       0.96      0.96      0.96       436
# weighted avg       0.97      0.97      0.97       436
#
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.73      0.79       267
#          1.0       0.71      0.84      0.77       211
#
#     accuracy                           0.78       478
#    macro avg       0.78      0.78      0.78       478
# weighted avg       0.79      0.78      0.78       478
#
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.77      0.82       434
#          1.0       0.59      0.77      0.67       193
#
#     accuracy                           0.77       627
#    macro avg       0.74      0.77      0.74       627
# weighted avg       0.79      0.77      0.77       627
#
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.87      0.83       310
#          1.0       0.55      0.41      0.47       121
#
#     accuracy                           0.74       431
#    macro avg       0.67      0.64      0.65       431
# weighted avg       0.72      0.74      0.73       431
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.83      0.90       130
#          1.0       0.93      1.00      0.96       285
#
#     accuracy                           0.94       415
#    macro avg       0.96      0.91      0.93       415
# weighted avg       0.95      0.94      0.94       415
#
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.73      0.80       324
#          1.0       0.76      0.91      0.83       305
#
#     accuracy                           0.82       629
#    macro avg       0.83      0.82      0.82       629
# weighted avg       0.83      0.82      0.82       629
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.88      0.92       112
#          1.0       0.95      0.98      0.97       268
#
#     accuracy                           0.95       380
#    macro avg       0.95      0.93      0.94       380
# weighted avg       0.95      0.95      0.95       380
#
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.84      0.87       492
#          1.0       0.69      0.80      0.74       228
#
#     accuracy                           0.82       720
#    macro avg       0.80      0.82      0.81       720
# weighted avg       0.83      0.82      0.83       720
#
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.80      0.82       467
#          1.0       0.73      0.78      0.75       318
#
#     accuracy                           0.79       785
#    macro avg       0.78      0.79      0.79       785
# weighted avg       0.80      0.79      0.79       785
#
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.81      0.83       408
#          1.0       0.62      0.70      0.66       182
#
#     accuracy                           0.78       590
#    macro avg       0.74      0.76      0.75       590
# weighted avg       0.79      0.78      0.78       590
#
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.68      0.78       237
#          1.0       0.83      0.96      0.89       394
#
#     accuracy                           0.85       631
#    macro avg       0.87      0.82      0.83       631
# weighted avg       0.86      0.85      0.85       631
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.85      0.91       150
#          1.0       0.91      0.98      0.94       224
#
#     accuracy                           0.93       374
#    macro avg       0.94      0.92      0.93       374
# weighted avg       0.93      0.93      0.93       374
#
# Test Prediction Loss:  0.3956041634082794
# Test Avg F1-score weighted:  0.8274600800245893
# Test Avg F1-score macro:  0.7930500936114075
# Test Class F1-score weighted:  [0.79021398 0.76731484 0.79906121 0.80208878 0.72560615 0.93676167
#  0.9059135  0.68685424 0.96551232 0.77890748 0.77386664 0.72774962
#  0.94312812 0.8160751  0.95210268 0.82793985 0.793428   0.7798008
#  0.84727137 0.92960524]
# Test Class F1-score macro:  [0.66852288 0.72402835 0.75840439 0.80206101 0.52620114 0.92585361
#  0.89383054 0.63941635 0.961704   0.77792777 0.74494015 0.64969521
#  0.9324243  0.81642773 0.94178922 0.80511278 0.787043   0.74656357
#  0.83305216 0.92600371]

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir attention
